# %%
pip install -U labelme2coco
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Collecting sahi>=0.8.19
#   Downloading sahi-0.11.7-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.8/dist-packages (from labelme2coco) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6.0->labelme2coco) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6.0->labelme2coco) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6.0->labelme2coco) (5.10.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6.0->labelme2coco) (3.11.0)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from sahi>=0.8.19->labelme2coco) (2.0.0)
# Collecting pybboxes==0.1.5
#   Downloading pybboxes-0.1.5-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from sahi>=0.8.19->labelme2coco) (2.23.0)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/lib/python3.8/dist-packages (from sahi>=0.8.19->labelme2coco) (4.64.1)
# Collecting pillow>=8.2.0
#   Downloading Pillow-9.3.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 22.9 MB/s
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from sahi>=0.8.19->labelme2coco) (6.0)
# Collecting click==8.0.4
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.8 MB/s
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.8/dist-packages (from sahi>=0.8.19->labelme2coco) (4.6.0.66)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 6.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pybboxes==0.1.5->sahi>=0.8.19->labelme2coco) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from fire->sahi>=0.8.19->labelme2coco) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.8/dist-packages (from fire->sahi>=0.8.19->labelme2coco) (2.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->sahi>=0.8.19->labelme2coco) (2.10)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116949 sha256=c56690a3b7a28d9319a5de6efb383012e1592f839dbb5da51a64b90a77ae1c12
#   Stored in directory: /root/.cache/pip/wheels/5b/eb/43/7295e71293b218ddfd627f935229bf54af9018add7fbb5aac6
# Successfully built fire
# Installing collected packages: terminaltables, pybboxes, pillow, fire, click, sahi, labelme2coco
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.4 which is incompatible.
# Successfully installed click-8.0.4 fire-0.5.0 labelme2coco-0.2.1 pillow-9.3.0 pybboxes-0.1.5 sahi-0.11.7 terminaltables-3.1.10

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import package
import labelme2coco

# set directory that contains labelme annotations and image files
labelme_folder = "drive/My Drive/Colab Notebooks/Tubes_SDR/Dataset_K16"

# set export dir
export_dir = "drive/My Drive/Colab Notebooks/Tubes_SDR/COCO/"

# set train split rate
train_split_rate = 0.85

# convert labelme annotations to coco
labelme2coco.convert(labelme_folder, export_dir, train_split_rate)
# Out:
# There are 111 listed files in folder Dataset_K16.
# Converting labelme annotations to COCO format: 100%|██████████| 111/111 [00:00<00:00, 154.69it/s]
